# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 3, 23, 17, 41, 1, 293705)

# %% [markdown]
# # Notebook Demo

# %% [markdown]
# ## Second Heading!

# %%
datetime.year

# %% [markdown]
# #### Heading 4

# %% [markdown]
# **this is bold**

# %% [markdown]
# <div class="alert alert-block alert-info">
#     Blue boxes (alert-info)
# </div>

# %%
from IPython.display import Image
Image(url="https://www.srikanthtechnologies.com/banner.jpg")
# Out:
# <img src="https://www.srikanthtechnologies.com/banner.jpg"/>

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 482A-6FBC
#
#  Directory of C:\classroom\mar20
#
# 21-03-2026  18:16    <DIR>          .
# 21-03-2026  17:14    <DIR>          ..
# 21-03-2026  17:56    <DIR>          .ipynb_checkpoints
# 21-03-2026  17:45    <DIR>          .virtual_documents
# 21-03-2026  18:16             2,820 nb_demo.ipynb
#                1 File(s)          2,820 bytes
#                4 Dir(s)  810,340,319,232 bytes free

# %%
# !cd
# Out:
# C:\classroom\mar20

# %%
# !type names.txt
# Out:
# Numpy
# Pandas
# Sckit-learn
# Matplotlib
# Seaborn
# TensorFlow

# %%
names = !type names.txt

# %%
names
# Out:
# ['Numpy', 'Pandas', 'Sckit-learn', 'Matplotlib', 'Seaborn', 'TensorFlow']
